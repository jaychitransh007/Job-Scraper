# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import pandas as pd
import math
import time
from collections import OrderedDict

# %% [markdown]
# ### Search Page

# %%
url = 'https://www.naukri.com/data-analyst-jobs-in-india'
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
request = urllib.request.Request(url,headers={'User-Agent': user_agent})
response = urllib.request.urlopen(request)
html = response.read()

# %%
soup = BeautifulSoup(html, "lxml")

# %% [markdown]
# ### Job-Links in the Page

# %%
all_link = []
for link in soup.select('a[href]'):
    if 'job-listings' in str(link.get('href')):
        all_link.append(link.get('href'))

#all_link[2]

# %% [markdown]
# ### Trial with one link

# %%
jd_url = all_link[2]

jd_source_mid = urllib.request.Request(jd_url,headers={'User-Agent': user_agent})
jd_source = urllib.request.urlopen(jd_source_mid)
jd_soup = BeautifulSoup(jd_source,"lxml")

# %%
#basic details

#location
location = jd_soup.find("div",{"class":"loc"}).getText().strip()
print ('Location: ' + location + '\n\n')

# Job Description
jd_text = jd_soup.find("ul",{"itemprop":"description"}).getText().strip()
print ('Description: '+ jd_text + '\n\n')

# Experience Level
experience = jd_soup.find("span",{"itemprop":"experienceRequirements"}).getText().strip()
print ('Experince: ' + experience)
# Out:
# Location: Pune
#
#
# Description: Department          : IPO/ Big Data Analyst   Profile     Well conversant with Big Data analysis work.  	Hand on experience of preparing reports ,data interpretation and data cleaning.  	Good Communication Skills. Good Power Point Presentation and Excel Skills  	Basic understanding of Big Data Tools and usage.
#
#
# Experince: 3 - 4 yrs

# %%
#Labels

labels = ['Salary', 'Industry', 'Functional Area', 'Role Category', 'Design Role']
role_info = []
for content in jd_soup.find("div",{"class":"jDisc mt20"}).contents:
    if len(str(content).replace(' ','')) != 0:
        info = content.getText().split(":")[-1].strip()
        role_info.append(info)
        
role_info_dict = {label: role_info for label, role_info in zip(labels, role_info)}
role_info_dict
# Out:
# {'Design Role': 'Business Analyst',
#  'Functional Area': 'IT Software - DBA   ,     Datawarehousing',
#  'Industry': 'Construction  /    Engineering  /    Cement  /    Metals',
#  'Role Category': 'System Design/Implementation/ERP/CRM',
#  'Salary': 'Not Disclosed by Recruiter'}

# %%
# Role Level Information

labels = ['Salary', 'Industry', 'Functional Area', 'Role Category', 'Design Role']
role_info = [content.getText().split(':')[-1].strip() for content in jd_soup.find("div",{"class":"jDisc mt20"}).contents 
 if len(str(content).replace(' ',''))!=0]

role_info_dict = {label: role_info for label, role_info in zip(labels, role_info)}
print (role_info_dict)
# Out:
# {'Salary': 'Not Disclosed by Recruiter', 'Industry': 'Construction  /    Engineering  /    Cement  /    Metals', 'Functional Area': 'IT Software - DBA   ,     Datawarehousing', 'Role Category': 'System Design/Implementation/ERP/CRM', 'Design Role': 'Business Analyst'}

# %%
# Skills required

key_skills = []
for skill in jd_soup.find("div",{"class":"ksTags"}).getText().split('  ')[1:]:
    key_skills.append(skill)
print (key_skills)
# Out:
# ['excel', 'data analysis', 'data interpretation', 'report preparation', 'big data', 'power point presentation', 'data cleaning ']

# %%
# Education Level
edu_info = [content.getText().split(':') for content in jd_soup.find("div",{"itemprop":"educationRequirements"}).contents 
 if len(str(content).replace(' ',''))!=0]

edu_info_dict = {label.strip(): edu_info.strip() for label, edu_info in edu_info}

# Sometimes the education information for one of the degrees can be missing
edu_labels = ['UG', 'PG', 'Doctorate']
for l in edu_labels:
    if l not in edu_info_dict.keys():
        edu_info_dict[l] = ''
print (edu_info_dict)
# Out:
# {'UG': 'B.Tech/B.E. - Any Specialization, Computers', 'PG': 'Any Postgraduate - Any Specialization', 'Doctorate': 'Doctorate Not Required'}

# %%
# Company Info
company_name = jd_soup.find("div",{"itemprop":"hiringOrganization"}).contents[1].p.getText()
print (company_name)
# Out:
# Hyster-Yale Lift Trucks India Pvt Ltd

# %%
naukri_df = pd.DataFrame()
column_names = ['Location', 'Link', 'Job Description', 'Experience','Salary', 'Industry', 'Functional Area', 'Role Category', 
                'Design Role', 'Skills','Company Name', 
                'UG','PG','Doctorate']

# %%
from collections import OrderedDict
df_dict = OrderedDict({'Location':location, 'Link':all_link[0],'Job Description':jd_text,'Experience':experience,
                       'Skills':key_skills,'Company Name':company_name})
df_dict.update(role_info_dict)
df_dict.update(edu_info_dict)
df_dict
# Out:
# OrderedDict([('Location', 'Pune'),
#              ('Link',
#               'https://www.naukri.com/job-listings-Business-Analyst-Big-data-Analyst-Mindgensolutions-Bengaluru-6-to-10-years-030718901257?src=jobsearchDesk&sid=15306470299349&xp=1&px=1'),
#              ('Job Description',
#               'Department          : IPO/ Big Data Analyst   Profile     Well conversant with Big Data analysis work.  \tHand on experience of preparing reports ,data interpretation and data cleaning.  \tGood Communication Skills. Good Power Point Presentation and Excel Skills  \tBasic understanding of Big Data Tools and usage.'),
#              ('Experience', '3 - 4 yrs'),
#              ('Skills',
#               ['excel',
#                'data analysis',
#                'data interpretation',
#                'report preparation',
#                'big data',
#                'power point presentation',
#                'data cleaning ']),
#              ('Company Name', 'Hyster-Yale Lift Trucks India Pvt Ltd'),
#              ('Salary', 'Not Disclosed by Recruiter'),
#              ('Industry',
#               'Construction  /    Engineering  /    Cement  /    Metals'),
#              ('Functional Area', 'IT Software - DBA   ,     Datawarehousing'),
#              ('Role Category', 'System Design/Implementation/ERP/CRM'),
#              ('Design Role', 'Business Analyst'),
#              ('UG', 'B.Tech/B.E. - Any Specialization, Computers'),
#              ('PG', 'Any Postgraduate - Any Specialization'),
#              ('Doctorate', 'Doctorate Not Required')])

# %%
naukri_df = naukri_df.append(df_dict,ignore_index=True)
naukri_df
# Out:
#                             Company Name       Design Role  \
# 0  Hyster-Yale Lift Trucks India Pvt Ltd  Business Analyst
#
#                 Doctorate Experience  \
# 0  Doctorate Not Required  3 - 4 yrs
#
#                              Functional Area  \
# 0  IT Software - DBA   ,     Datawarehousing
#
#                                             Industry  \
# 0  Construction  /    Engineering  /    Cement  /...
#
#                                      Job Description  \
# 0  Department          : IPO/ Big Data Analyst   ...
#
#                                                 Link Location  \
# 0  https://www.naukri.com/job-listings-Business-A...     Pune
#
#                                       PG  \
# 0  Any Postgraduate - Any Specialization
#
#                           Role Category                      Salary  \
# 0  System Design/Implementation/ERP/CRM  Not Disclosed by Recruiter
#
#                                               Skills  \
# 0  [excel, data analysis, data interpretation, re...
#
#                                             UG
# 0  B.Tech/B.E. - Any Specialization, Computers

# %%
# Reordering the columns to a preferred order as specified

naukri_df = naukri_df.reindex(columns=column_names)
naukri_df
# Out:
#   Location                                               Link  \
# 0     Pune  https://www.naukri.com/job-listings-Business-A...
#
#                                      Job Description Experience  \
# 0  Department          : IPO/ Big Data Analyst   ...  3 - 4 yrs
#
#                        Salary  \
# 0  Not Disclosed by Recruiter
#
#                                             Industry  \
# 0  Construction  /    Engineering  /    Cement  /...
#
#                              Functional Area  \
# 0  IT Software - DBA   ,     Datawarehousing
#
#                           Role Category       Design Role  \
# 0  System Design/Implementation/ERP/CRM  Business Analyst
#
#                                               Skills  \
# 0  [excel, data analysis, data interpretation, re...
#
#                             Company Name  \
# 0  Hyster-Yale Lift Trucks India Pvt Ltd
#
#                                             UG  \
# 0  B.Tech/B.E. - Any Specialization, Computers
#
#                                       PG               Doctorate
# 0  Any Postgraduate - Any Specialization  Doctorate Not Required

# %%
# Together into one function
labels = ['Salary', 'Industry', 'Functional Area', 'Role Category', 'Design Role']
edu_labels = ['UG', 'PG', 'Doctorate']
naukri_df = pd.DataFrame()
           
for page_url in all_link:
    #page_url = base_url+str(page)
    jd_source = urllib.request.Request(page_url, headers = {'User-Agent' : user_agent})
    jd_html = urllib.request.urlopen(jd_source).read()
    jd_soup = BeautifulSoup(jd_html,"lxml")
    #all_links = [link.get('href') for link in soup.findAll('a') if 'job-listings' in  str(link.get('href'))]
    #for url in all_links:

    try:
        jd_text = jd_soup.find("ul",{"itemprop":"description"}).getText().strip()
        location = jd_soup.find("div",{"class":"loc"}).getText().strip()
        experience = jd_soup.find("span",{"itemprop":"experienceRequirements"}).getText().strip()
            
        role_info = [content.getText().split(':')[-1].strip() for content in jd_soup.find("div",{"class":"jDisc mt20"}).contents if len(str(content).replace(' ',''))!=0]
        role_info_dict = {label: role_info for label, role_info in zip(labels, role_info)}
            
        key_skills = '|'.join(jd_soup.find("div",{"class":"ksTags"}).getText().split('  '))[1:]

        edu_info = [content.getText().split(':') for content in jd_soup.find("div",{"itemprop":"educationRequirements"}).contents if len(str(content).replace(' ',''))!=0]
        edu_info_dict = {label.strip(): edu_info.strip() for label, edu_info in edu_info}
        for l in edu_labels:
            if l not in edu_info_dict.keys():
                edu_info_dict[l] = ''

        company_name = jd_soup.find("div",{"itemprop":"hiringOrganization"}).contents[1].p.getText().strip()
        
    except AttributeError:
        continue
    df_dict = OrderedDict({'Location':location, 'Link':url,'Job Description':jd_text,'Experience':experience,'Skills':key_skills,'Company Name':company_name})
    df_dict.update(role_info_dict)
    df_dict.update(edu_info_dict)
    naukri_df = naukri_df.append(df_dict,ignore_index=True)
    time.sleep(1)

# %%
naukri_df
# Out:
#                                          Company Name  \
# 0                                    Mindgensolutions
# 1               Hyster-Yale Lift Trucks India Pvt Ltd
# 2                     Cactus Communications Pvt. Ltd.
# 3                        The Akshaya Patra Foundation
# 4                       INFOR (INDIA) PRIVATE LIMITED
# 5                          Skan Consultancy Pvt. Ltd.
# 6                           2Coms Consulting Pvt Ltd.
# 7                                      Risk Resources
# 8            Iflate Softsystems India Private Limited
# 9   FIL India Business and Research Services Priva...
# 10                      Client of Synergy Consultants
# 11                        TVS Credit Services Limited
# 12         HEWLETT PACKARD ENTERPRISE PRIVATE LIMITED
# 13    Cargill Business Services India Private Limited
# 14                        FutureTrack Edutech Pvt Ltd
# 15  FIL India Business and Research Services Priva...
# 16  FIL India Business and Research Services Priva...
# 17                                   Nikos Consulting
# 18             Liventus Technology Services Pvt. Ltd.
# 19             Liventus Technology Services Pvt. Ltd.
# 20                                       Pharma Focus
# 21                           Sim Technologies Pvt.Ltd
# 22                                  SAP India Pvt.Ltd
# 23  FIL India Business and Research Services Priva...
# 24            INFOSEARCH BPO SERVICES PVT LTD Limited
# 25             Zolostays Property Solutions Pvt. Ltd.
# 26                     SHAKTI INFOSOLUTIONS PVT. LTD.
# 27                                            Premium
# 28                  Professional Consultancy Services
# 29              WSP CONSULTANTS INDIA PRIVATE LIMITED
# 30                            Cargill India Pvt. Ltd.
# 31                                         Affordplan
# 32                           M & C Saatchi Mobile LLP
# 33                  Veritis Solutions India Pvt. Ltd.
# 34          Amdocs Development Center India Pvt. Ltd.
#
#                                   Design Role  \
# 0                            Business Analyst
# 1                            Business Analyst
# 2                                Data Analyst
# 3   Quality Assurance/Quality Control Manager
# 4                                Data Analyst
# 5                                Data Analyst
# 6                                Data Analyst
# 7                           Analytics Manager
# 8                                     Fresher
# 9                                Data Analyst
# 10                           Business Analyst
# 11                          Analytics Manager
# 12                               Data Analyst
# 13                               Data Analyst
# 14                               Data Analyst
# 15                               Data Analyst
# 16                               Data Analyst
# 17                                        DBA
# 18                               Data Analyst
# 19                               Data Analyst
# 20                           Business Analyst
# 21                                        DBA
# 22                   Team Lead/Technical Lead
# 23                               Data Analyst
# 24                               Data Analyst
# 25                               Data Analyst
# 26                         Software Developer
# 27                               Data Analyst
# 28                               Data Analyst
# 29                               Data Analyst
# 30                               HR Executive
# 31                               Data Analyst
# 32                               Data Analyst
# 33                       Business/EDP Analyst
# 34                           Business Analyst
#
#                                             Doctorate  Experience  \
# 0                              Doctorate Not Required  6 - 10 yrs
# 1                              Doctorate Not Required   3 - 4 yrs
# 2                              Doctorate Not Required   2 - 5 yrs
# 3                              Doctorate Not Required   4 - 6 yrs
# 4                                                       5 - 6 yrs
# 5                                                       2 - 5 yrs
# 6                              Doctorate Not Required   1 - 3 yrs
# 7                              Doctorate Not Required   2 - 6 yrs
# 8                                                       1 - 5 yrs
# 9   Ph.D - Computers, Economics, Finance, Maths, S...   3 - 6 yrs
# 10                             Doctorate Not Required  5 - 10 yrs
# 11                 Any Doctorate - Any Specialization   4 - 4 yrs
# 12                             Doctorate Not Required   5 - 8 yrs
# 13                             Doctorate Not Required   4 - 7 yrs
# 14                             Doctorate Not Required   3 - 5 yrs
# 15  Ph.D - Computers, Economics, Finance, Maths, S...   3 - 5 yrs
# 16  Ph.D - Maths, Statistics, Economics, Computers...   3 - 5 yrs
# 17                             Doctorate Not Required   2 - 4 yrs
# 18                                                     5 - 10 yrs
# 19                                                      2 - 5 yrs
# 20                                                      4 - 6 yrs
# 21                                                      1 - 3 yrs
# 22                                                      4 - 6 yrs
# 23     Ph.D - Computers, Economics, Maths, Statistics   3 - 6 yrs
# 24                                                      0 - 3 yrs
# 25                                                      2 - 6 yrs
# 26                             Doctorate Not Required   4 - 8 yrs
# 27                                                      2 - 3 yrs
# 28                             Doctorate Not Required   3 - 6 yrs
# 29                             Doctorate Not Required   6 - 8 yrs
# 30                                                      4 - 6 yrs
# 31                             Doctorate Not Required   2 - 5 yrs
# 32                             Doctorate Not Required   2 - 3 yrs
# 33                 Any Doctorate - Any Specialization   3 - 6 yrs
# 34                                                      4 - 7 yrs
#
#                                       Functional Area  \
# 0                   Analytics & Business Intelligence
# 1           IT Software - DBA   ,     Datawarehousing
# 2                   Analytics & Business Intelligence
# 3   Production   ,     Manufacturing   ,     Maint...
# 4                   Analytics & Business Intelligence
# 5                   Analytics & Business Intelligence
# 6                   Analytics & Business Intelligence
# 7                   Analytics & Business Intelligence
# 8   ITES   ,     BPO   ,     KPO   ,     LPO   ,  ...
# 9                   Analytics & Business Intelligence
# 10                  Analytics & Business Intelligence
# 11                  Analytics & Business Intelligence
# 12                  Analytics & Business Intelligence
# 13                  Analytics & Business Intelligence
# 14                  Analytics & Business Intelligence
# 15                  Analytics & Business Intelligence
# 16                  Analytics & Business Intelligence
# 17          IT Software - DBA   ,     Datawarehousing
# 18                  Analytics & Business Intelligence
# 19                  Analytics & Business Intelligence
# 20  IT Software - Application Programming   ,     ...
# 21          IT Software - DBA   ,     Datawarehousing
# 22  IT Software - Application Programming   ,     ...
# 23                  Analytics & Business Intelligence
# 24                  Analytics & Business Intelligence
# 25                  Analytics & Business Intelligence
# 26  IT Software - Application Programming   ,     ...
# 27                  Analytics & Business Intelligence
# 28                  Analytics & Business Intelligence
# 29                  Analytics & Business Intelligence
# 30  HR   ,     Recruitment   ,     Administration ...
# 31                  Analytics & Business Intelligence
# 32                  Analytics & Business Intelligence
# 33  ITES   ,     BPO   ,     KPO   ,     LPO   ,  ...
# 34  IT Software - Application Programming   ,     ...
#
#                                              Industry  \
# 0                 IT-Software  /    Software Services
# 1   Construction  /    Engineering  /    Cement  /...
# 2                  KPO  /    Research  /    Analytics
# 3                     FMCG  /    Foods  /    Beverage
# 4                 IT-Software  /    Software Services
# 5                                         Telecom/ISP
# 6                 IT-Software  /    Software Services
# 7                  KPO  /    Research  /    Analytics
# 8                    BPO  /    Call Centre  /    ITES
# 9      Banking  /    Financial Services  /    Broking
# 10                IT-Software  /    Software Services
# 11     Banking  /    Financial Services  /    Broking
# 12                IT-Software  /    Software Services
# 13     Banking  /    Financial Services  /    Broking
# 14         Strategy  /    Management Consulting Firms
# 15     Banking  /    Financial Services  /    Broking
# 16     Banking  /    Financial Services  /    Broking
# 17                IT-Software  /    Software Services
# 18                IT-Software  /    Software Services
# 19                IT-Software  /    Software Services
# 20       Pharma  /    Biotech  /    Clinical Research
# 21                   BPO  /    Call Centre  /    ITES
# 22                IT-Software  /    Software Services
# 23     Banking  /    Financial Services  /    Broking
# 24                 KPO  /    Research  /    Analytics
# 25                           Internet  /    Ecommerce
# 26                IT-Software  /    Software Services
# 27                IT-Software  /    Software Services
# 28  NGO  /    Social Services  /    Regulators  / ...
# 29  Construction  /    Engineering  /    Cement  /...
# 30                                    Food Processing
# 31                IT-Software  /    Software Services
# 32           Media  /    Entertainment  /    Internet
# 33                IT-Software  /    Software Services
# 34                                        Telecom/ISP
#
#                                       Job Description  \
# 0   Job Description   -Business Analyst  -Big data...
# 1   Department          : IPO/ Big Data Analyst   ...
# 2   Want to work with India's no.1 mid-sized compa...
# 3   Qualification & Experience: Experience in Food...
# 4   Infor Cloud Management is a strategic, global ...
# 5   Develop Data Analysis Generate Business Report...
# 6   Dear Job Seekers,        Greetings from 2 Com'...
# 7   Senior Analyst/Manager - Data Analytics - Fina...
# 8   Must have excellent oral & written skills\r\nE...
# 9   Role Description:  This role involves working ...
# 10  Responsibilities & Qualifications  Overview: T...
# 11  Perform data analysis, understand trends and p...
# 12  Job Description:  The EFR - Revenue Analytics ...
# 13  The Master Data Analyst position will be a ste...
# 14  Primary Responsibilities:  - Carry out work to...
# 15  Description  Business Unit Overview  Business ...
# 16  Description  Business Unit Overview  Business ...
# 17  Your Experience  :  - Experience in designing,...
# 18  Job Description:    We're looking for a highly...
# 19  Were looking for a Data Analyst who will be re...
# 20  Monthly data upload of Line of business, proje...
# 21  *Acquiring data from primary or secondary data...
# 22  Requisition ID: 188250   Work Area: Consulting...
# 23  Role Description      This role involves worki...
# 24  1.Knowledge of database building via Google Se...
# 25  Senior Data Analyst  We are looking for a Sr. ...
# 26  5+ years of experience in a relevant industry....
# 27  Must Have  - Python & Machine Learning  - Appl...
# 28  Source and collect appropriate data. Create ea...
# 29  Role Summary We are looking for a passionate c...
# 30  Pulling the list/ custome/ advance reports fro...
# 31  - Atleast 2-4 yr experience in Analytics  - Ab...
# 32  Perform analysis of digital marketing campaign...
# 33  Data Analyst: Years of Experience: 3 to 6 year...
# 34  Ability to work as a Migration Analyst & Devel...
#
#                                                  Link  \
# 0   https://www.naukri.com/data-analyst-jobs-in-india
# 1   https://www.naukri.com/data-analyst-jobs-in-india
# 2   https://www.naukri.com/data-analyst-jobs-in-india
# 3   https://www.naukri.com/data-analyst-jobs-in-india
# 4   https://www.naukri.com/data-analyst-jobs-in-india
# 5   https://www.naukri.com/data-analyst-jobs-in-india
# 6   https://www.naukri.com/data-analyst-jobs-in-india
# 7   https://www.naukri.com/data-analyst-jobs-in-india
# 8   https://www.naukri.com/data-analyst-jobs-in-india
# 9   https://www.naukri.com/data-analyst-jobs-in-india
# 10  https://www.naukri.com/data-analyst-jobs-in-india
# 11  https://www.naukri.com/data-analyst-jobs-in-india
# 12  https://www.naukri.com/data-analyst-jobs-in-india
# 13  https://www.naukri.com/data-analyst-jobs-in-india
# 14  https://www.naukri.com/data-analyst-jobs-in-india
# 15  https://www.naukri.com/data-analyst-jobs-in-india
# 16  https://www.naukri.com/data-analyst-jobs-in-india
# 17  https://www.naukri.com/data-analyst-jobs-in-india
# 18  https://www.naukri.com/data-analyst-jobs-in-india
# 19  https://www.naukri.com/data-analyst-jobs-in-india
# 20  https://www.naukri.com/data-analyst-jobs-in-india
# 21  https://www.naukri.com/data-analyst-jobs-in-india
# 22  https://www.naukri.com/data-analyst-jobs-in-india
# 23  https://www.naukri.com/data-analyst-jobs-in-india
# 24  https://www.naukri.com/data-analyst-jobs-in-india
# 25  https://www.naukri.com/data-analyst-jobs-in-india
# 26  https://www.naukri.com/data-analyst-jobs-in-india
# 27  https://www.naukri.com/data-analyst-jobs-in-india
# 28  https://www.naukri.com/data-analyst-jobs-in-india
# 29  https://www.naukri.com/data-analyst-jobs-in-india
# 30  https://www.naukri.com/data-analyst-jobs-in-india
# 31  https://www.naukri.com/data-analyst-jobs-in-india
# 32  https://www.naukri.com/data-analyst-jobs-in-india
# 33  https://www.naukri.com/data-analyst-jobs-in-india
# 34  https://www.naukri.com/data-analyst-jobs-in-india
#
#                                              Location  \
# 0                                           Bengaluru
# 1                                                Pune
# 2                                     Mumbai(Chakala)
# 3                                           Bengaluru
# 4                                           Hyderabad
# 5                                              Mumbai
# 6                              Bengaluru(Singasandra)
# 7                                           Hyderabad
# 8                                           Hyderabad
# 9                                           Bengaluru
# 10                                          Bengaluru
# 11                              Chennai(Nungambakkam)
# 12                                          Bengaluru
# 13                                          Karnataka
# 14                                             Mumbai
# 15                                          Bengaluru
# 16                                          Bengaluru
# 17                                             Mumbai
# 18                                          Bengaluru
# 19                                          Bengaluru
# 20                                          Bengaluru
# 21                             Chennai(Ekkaduthangal)
# 22                                          Bengaluru
# 23                                          Bengaluru
# 24  Chennai(Royapettah, Mount Road, Gopalapuram, T...
# 25                                          Bengaluru
# 26                                            Chennai
# 27                                             Mumbai
# 28                                            Chennai
# 29                                              Noida
# 30                                          Bengaluru
# 31                                              Delhi
# 32                                Delhi NCR,    Delhi
# 33                                          Hyderabad
# 34                                               Pune
#
#                                                    PG  \
# 0               Any Postgraduate - Any Specialization
# 1               Any Postgraduate - Any Specialization
# 2                                    Any Postgraduate
# 3   MS/M.Sc(Science) - Any Specialization, Food Te...
# 4                              CA, MBA/PGDM - Finance
# 5
# 6
# 7                                  MBA/PGDM - Finance
# 8
# 9   M.A - Maths, Statistics, Economics, MS/M.Sc(Sc...
# 10                      MBA/PGDM - Any Specialization
# 11    MS/M.Sc(Science) - Statistics, M.A - Statistics
# 12              Any Postgraduate - Any Specialization
# 13              Any Postgraduate - Any Specialization
# 14  M.A - Economics, MS/M.Sc(Science) - Maths, Sta...
# 15  M.Tech - Computers, MCA - Computers, MS/M.Sc(S...
# 16  M.Tech - Any Specialization, MCA - Computers, ...
# 17              Any Postgraduate - Any Specialization
# 18  MS/M.Sc(Science) - Any Specialization, MBA/PGD...
# 19                                    MCA - Computers
# 20             MBA/PGDM - Any Specialization, Finance
# 21              Any Postgraduate - Any Specialization
# 22                                 M.Tech - Computers
# 23  M.Tech - Any Specialization, Computers, MCA - ...
# 24
# 25                      MBA/PGDM - Any Specialization
# 26                                   Any Postgraduate
# 27              Any Postgraduate - Any Specialization
# 28                       Post Graduation Not Required
# 29              Any Postgraduate - Any Specialization
# 30                 MBA/PGDM - HR/Industrial Relations
# 31              Any Postgraduate - Any Specialization
# 32                                              Other
# 33              Any Postgraduate - Any Specialization
# 34                                 M.Tech - Computers
#
#                                  Role Category  \
# 0                               Analytics & BI
# 1         System Design/Implementation/ERP/CRM
# 2                               Analytics & BI
# 3         Production/Manufacturing/Maintenance
# 4                               Analytics & BI
# 5                               Analytics & BI
# 6                               Analytics & BI
# 7                               Analytics & BI
# 8                                        Other
# 9                               Analytics & BI
# 10                              Analytics & BI
# 11                              Analytics & BI
# 12                              Analytics & BI
# 13                              Analytics & BI
# 14                              Analytics & BI
# 15                              Analytics & BI
# 16                              Analytics & BI
# 17  Admin/Maintenance/Security/Datawarehousing
# 18                              Analytics & BI
# 19                              Analytics & BI
# 20        System Design/Implementation/ERP/CRM
# 21  Admin/Maintenance/Security/Datawarehousing
# 22                        Programming & Design
# 23                              Analytics & BI
# 24                              Analytics & BI
# 25                              Analytics & BI
# 26                        Programming & Design
# 27                              Analytics & BI
# 28                              Analytics & BI
# 29                              Analytics & BI
# 30                        HR/ Recruitment / IR
# 31                              Analytics & BI
# 32                              Analytics & BI
# 33                                  Operations
# 34        System Design/Implementation/ERP/CRM
#
#                                                Salary  \
# 0                          Not Disclosed by Recruiter
# 1                          Not Disclosed by Recruiter
# 2                          Not Disclosed by Recruiter
# 3                          Not Disclosed by Recruiter
# 4                          Not Disclosed by Recruiter
# 5                          Not Disclosed by Recruiter
# 6                     INR    4,00,000 - 4,50,000 P.A.
# 7                          Not Disclosed by Recruiter
# 8   INR    1,00,000 - 5,00,000 P.A. Salary + Medic...
# 9                          Not Disclosed by Recruiter
# 10                         Not Disclosed by Recruiter
# 11                         Not Disclosed by Recruiter
# 12                         Not Disclosed by Recruiter
# 13                         Not Disclosed by Recruiter
# 14                         Not Disclosed by Recruiter
# 15                         Not Disclosed by Recruiter
# 16                         Not Disclosed by Recruiter
# 17                         Not Disclosed by Recruiter
# 18                   INR    6,00,000 - 15,00,000 P.A.
# 19                    INR    4,00,000 - 8,00,000 P.A.
# 20                   INR    9,00,000 - 12,00,000 P.A.
# 21                         Not Disclosed by Recruiter
# 22                         Not Disclosed by Recruiter
# 23                         Not Disclosed by Recruiter
# 24                                   Best in Industry
# 25                         Not Disclosed by Recruiter
# 26                               Best in the Industry
# 27                         Not Disclosed by Recruiter
# 28                         Not Disclosed by Recruiter
# 29                         Not Disclosed by Recruiter
# 30                         Not Disclosed by Recruiter
# 31                         Not Disclosed by Recruiter
# 32                         Not Disclosed by Recruiter
# 33                         Not Disclosed by Recruiter
# 34                         Not Disclosed by Recruiter
#
#                                                Skills  \
# 0   Business Analysis|Statistical Modeling|Data An...
# 1   excel|data analysis|data interpretation|report...
# 2   data science|big data|statistical modeling|sta...
# 3   food technology|food quality control|customer ...
# 4   Business Finance|Financial Management|Report G...
# 5   data analysis|reporting tools|analysis|data mi...
# 6   Data Analysis|SQL|Advanced Excel|Macros|Query|...
# 7   financial research|finance|fundamental researc...
# 8   call center|voice process|international bpo|bp...
# 9   Text Mining|C|R|Data Mining|Data Science|Machi...
# 10  Business Analysis|Business Intelligence|Analyt...
# 11  data analysis|business intelligence|business a...
# 12  Revenue Data Analyst|GAAP|Accounting|Finance|d...
# 13  Master Data|Service Level|User Provisioning|Ma...
# 14  Data Analyst|Data Analysis|Visual Basic|SQL|nu...
# 15  Deep Learning|C|Artificial Intelligence|Python...
# 16  C|SAS|R|Machine Learning|Algorithms|Artificial...
# 17  Django|Python|MySQL|NoSQL|SQL Server|Linux|AWS...
# 18  Macros|VBA|Formulas|Data Analysis|Test Data|Sy...
# 19  data migration|data analysis|system testing|da...
# 20  data analyst|associate business analyst|busine...
# 21                    sql|mysql|Excel|Advanced Excel
# 22  Customer management|Six sigma|Healthcare|Procu...
# 23  Data Science|artificial intelligence|Advanced ...
# 24  internet research|data analysis|database build...
# 25  Data Analysis|Data Visualization|Data Mining|B...
# 26  Machine Learning|Python|Data Analysis|Data Ana...
# 27  data analysis|machine learning|python|data ana...
# 28  data analysis|data management|website manageme...
# 29  D3.Js|Algorithms|Excel|Computer Science|SQL|XM...
# 30  Python|Business objects|Consulting|Analytics|D...
# 31  Data Analyst|Data Management|Analytics|data an...
# 32  Data Analysis|data management|data optimizatio...
# 33         Data Analysis|Data Analytics|Data Analyst
# 34  CRM|Troubleshooting|Data analysis|English|Bill...
#
#                                                    UG
# 0   Any Graduate - Any Specialization, B.Sc - Stat...
# 1         B.Tech/B.E. - Any Specialization, Computers
# 2                                        Any Graduate
# 3          B.Sc - Any Specialization, Food Technology
# 4                   Any Graduate - Any Specialization
# 5                   Any Graduate - Any Specialization
# 6   Any Graduate - Any Specialization, B.Tech/B.E....
# 7                   Any Graduate - Any Specialization
# 8                   Any Graduate - Any Specialization
# 9                   Any Graduate - Any Specialization
# 10                   B.Tech/B.E. - Any Specialization
# 11                B.Sc - Statistics, B.A - Statistics
# 12  B.Com - Commerce, B.Sc - Statistics, B.Tech/B....
# 13                  Any Graduate - Any Specialization
# 14  B.Sc - Maths, Statistics, B.A - Economics, B.C...
# 15                  Any Graduate - Any Specialization
# 16                  Any Graduate - Any Specialization
# 17                            B.Tech/B.E. - Computers
# 18  B.Com - Commerce, B.Sc - Any Specialization, B...
# 19  B.Tech/B.E. - Any Specialization, B.Sc - Any S...
# 20
# 21                  Any Graduate - Any Specialization
# 22                            B.Tech/B.E. - Computers
# 23                  Any Graduate - Any Specialization
# 24                  Any Graduate - Any Specialization
# 25
# 26                                       Any Graduate
# 27                  Any Graduate - Any Specialization
# 28  B.Sc - Computers, Statistics, B.A - Any Specia...
# 29                  Any Graduate - Any Specialization
# 30                  Any Graduate - Any Specialization
# 31                  Any Graduate - Any Specialization
# 32                  Any Graduate - Any Specialization
# 33                                       Any Graduate
# 34                            B.Tech/B.E. - Computers
